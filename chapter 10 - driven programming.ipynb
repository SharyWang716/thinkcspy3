# %%
#keypress event
import turtle

turtle.setup(400,500) # Determine the window size
wn = turtle.Screen() # Get a reference to the window
wn.title("Handling keypresses!") # Change the window title
wn.bgcolor("lightgreen") # Set the background color
tess = turtle.Turtle() # Create our favorite turtle

# The next four functions are our "event handlers".
def h1():
    tess.forward(30)

def h2():
    tess.left(45)

def h3():
    tess.right(45)

def h4():
    wn.bye() # Close down the turtle window

# These lines "wire up" keypresses to the handlers we’ve defined.
wn.onkey(h1, "Up")
wn.onkey(h2, "Left")
wn.onkey(h3, "Right")
wn.onkey(h4, "q")

# Now we need to tell the window to start listening for events,
# If any of the keys that we’re monitoring is pressed, its
# handler will be called.
wn.listen()
wn.mainloop()

# %%
#mouse event
import turtle

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("How to handle mouse clicks on the window!")
wn.bgcolor("lightgreen")

tess = turtle.Turtle()
tess.color("purple")
tess.pensize(3)
tess.shape("circle")

def h1(x, y):
    wn.title("Got click at coords {0}, {1}".format(x, y))#标题显示坐标
    tess.goto(x, y) #鼠标点一下，给位置，它才走

wn.onclick(h1) # Wire up a click on the window.
wn.mainloop()

# %%
#two turtles
import turtle

turtle.setup(400,500) # Determine the window size
wn = turtle.Screen() # Get a reference to the window
wn.title("Handling mouse clicks!") # Change the window title
wn.bgcolor("lightgreen") # Set the background color
tess = turtle.Turtle() # Create two turtles
tess.color("purple")
alex = turtle.Turtle() # Move them apart
alex.color("blue")
alex.forward(100)

def handler_for_tess(x, y):
    wn.title("Tess clicked at {0}, {1}".format(x, y))
    tess.left(42)
    tess.forward(30)

def handler_for_alex(x, y):
    wn.title("Alex clicked at {0}, {1}".format(x, y))
    alex.right(84)
    alex.forward(50)

tess.onclick(handler_for_tess)
alex.onclick(handler_for_alex)

wn.mainloop()

# %%
#automatic events from a timer
import turtle

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Using a timer")
wn.bgcolor("lightgreen")

tess = turtle.Turtle()
tess.color("purple")
tess.pensize(3)

def h1():
    tess.forward(100)
    tess.left(56)

wn.ontimer(h1, 2000)#just use once
wn.mainloop()

# %%
import turtle

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Using a timer to get events!")
wn.bgcolor("lightgreen")

tess = turtle.Turtle()
tess.color("purple")

def h1():
    tess.forward(100)
    tess.left(56)
    wn.ontimer(h1, 60)

h1()
wn.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\ana\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\ana\lib\tkinter\__init__.py", line 749, in callit
#     func(*args)
#   File "<ipython-input-18-e9b8254b5cb8>", line 12, in h1
#     tess.forward(100)
#   File "D:\ana\lib\turtle.py", line 1637, in forward
#     self._go(distance)
#   File "D:\ana\lib\turtle.py", line 1605, in _go
#     self._goto(ende)
#   File "D:\ana\lib\turtle.py", line 3178, in _goto
#     self._pencolor, self._pensize, top)
#   File "D:\ana\lib\turtle.py", line 545, in _drawline
#     self.cv.coords(lineitem, *cl)
#   File "<string>", line 1, in coords
#   File "D:\ana\lib\tkinter\__init__.py", line 2469, in coords
#     self.tk.call((self._w, 'coords') + args))]
# _tkinter.TclError: invalid command name ".!canvas"

# %%
import turtle # Tess becomes a traffic light.

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Tess becomes a traffic light!")
wn.bgcolor("lightgreen")
tess = turtle.Turtle()


def draw_housing():
    """ Draw a nice housing to hold the traffic lights """
    tess.pensize(3)
    tess.color("black", "darkgrey")
    tess.begin_fill()
    tess.forward(80)
    tess.left(90)
    tess.forward(200)
    tess.circle(40, 180)
    tess.forward(200)
    tess.left(90)
    tess.end_fill()


draw_housing()

tess.penup()
# Position tess onto the place where the green light should be
tess.forward(40)
tess.left(90)
tess.forward(50)
# Turn tess into a big green circle
tess.shape("circle")
tess.shapesize(3)
tess.fillcolor("green")

# A traffic light is a kind of state machine with three states,
# Green, Orange, Red. We number these states 0, 1, 2
# When the machine changes state, we change tess’ position and
# her fillcolor.

# This variable holds the current state of the machine
state_num = 0


def advance_state_machine():
    global state_num #tell Python not to create a new local variable for state_num
    if state_num == 0: # Transition from state 0 to state 1
        tess.forward(70)
        tess.fillcolor("orange")
        state_num = 1
    elif state_num == 1: # Transition from state 1 to state 2
        tess.forward(70)
        tess.fillcolor("red")
        state_num = 2
    else: # Transition from state 2 to state 0
        tess.back(140)
        tess.fillcolor("green")
        state_num = 0

# Bind the event handler to the space key.
wn.onkey(advance_state_machine, "space")

wn.listen() # Listen for events
wn.mainloop()

# %%
#exercise 1
import turtle

turtle.setup(400,500) # Determine the window size
wn = turtle.Screen() # Get a reference to the window
wn.title("Handling keypresses!") # Change the window title
#wn.bgcolor("lightgreen") # Set the background color
tess = turtle.Turtle() # Create our favorite turtle
background_colors = ["lightgreen", "lightblue", "lightgray", "yellow"]
current_color = 0
wn.bgcolor(background_colors[current_color]) # Set the background color

PenSize = 1

# The next four functions are our "event handlers".
def h1():
    tess.forward(30)

def h2():
    tess.left(45)

def h3():
    tess.right(45)

def h4():
    wn.bye() # Close down the turtle window

def c1():
    tess.color("red")

def c2():
    tess.color("green")
    
def c3():
    tess.color("blue")
    
def w1():
    global PenSize
    PenSize += 1
    if PenSize > 20:
        PenSize = 20
    tess.pensize(PenSize)

def w2():
    global PenSize
    PenSize -= 1
    if PenSize < 1:
        PenSize = 1
    tess.pensize(PenSize)
    
def h5():
    global background_colors
    global current_color
    current_color = (current_color + 1) % 4
    wn.bgcolor(background_colors[current_color])
        
# These lines "wire up" keypresses to the handlers we’ve defined.
wn.onkey(h1, "Up")
wn.onkey(h2, "Left")
wn.onkey(h3, "Right")
wn.onkey(h4, "q")
wn.onkey(c1, "r")
wn.onkey(c2, "g")
wn.onkey(c3, "b")
wn.onkey(w1, "0")
wn.onkey(w2, "-")
wn.onkey(h5, "space")

# Now we need to tell the window to start listening for events,
# If any of the keys that we’re monitoring is pressed, its
# handler will be called.
wn.listen()
wn.mainloop()

# %%
#exercise 2, traffic ligiht with a timer
import turtle # Tess becomes a traffic light.

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Tess becomes a traffic light!")
wn.bgcolor("lightgreen")
tess = turtle.Turtle()


def draw_housing():
    """ Draw a nice housing to hold the traffic lights """
    tess.pensize(3)
    tess.color("black", "darkgrey")
    tess.begin_fill()
    tess.forward(80)
    tess.left(90)
    tess.forward(200)
    tess.circle(40, 180)
    tess.forward(200)
    tess.left(90)
    tess.end_fill()


draw_housing()

tess.penup()
# Position tess onto the place where the green light should be
tess.forward(40)
tess.left(90)
tess.forward(50)
# Turn tess into a big green circle
tess.shape("circle")
tess.shapesize(3)
tess.fillcolor("green")

# A traffic light is a kind of state machine with three states,
# Green, Orange, Red. We number these states 0, 1, 2
# When the machine changes state, we change tess’ position and
# her fillcolor.

# This variable holds the current state of the machine
state_num = 0


def advance_state_machine():
    global state_num #tell Python not to create a new local variable for state_num
    if state_num == 0: # Transition from state 0 to state 1
        tess.forward(70)
        tess.fillcolor("orange")
        state_num = 1
        
    elif state_num == 1: # Transition from state 1 to state 2
        tess.forward(70)
        tess.fillcolor("red")
        state_num = 2
    else: # Transition from state 2 to state 0
        tess.back(140)
        tess.fillcolor("green")
        state_num = 0
    wn.ontimer(advance_state_machine, 500)

# Bind the event handler to the space key.
#wn.onkey(advance_state_machine, "space")
advance_state_machine()
#wn.listen() # Listen for events
wn.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\ana\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "D:\ana\lib\tkinter\__init__.py", line 749, in callit
#     func(*args)
#   File "<ipython-input-40-27ae89b8ca4b>", line 49, in advance_state_machine
#     tess.forward(70)
#   File "D:\ana\lib\turtle.py", line 1637, in forward
#     self._go(distance)
#   File "D:\ana\lib\turtle.py", line 1605, in _go
#     self._goto(ende)
#   File "D:\ana\lib\turtle.py", line 3179, in _goto
#     self._update()
#   File "D:\ana\lib\turtle.py", line 2660, in _update
#     self._update_data()
#   File "D:\ana\lib\turtle.py", line 2646, in _update_data
#     self.screen._incrementudc()
#   File "D:\ana\lib\turtle.py", line 1292, in _incrementudc
#     raise Terminator
# turtle.Terminator

# %%
#exercise 3
import turtle # Tess becomes a traffic light.

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Tess becomes a traffic light!")
wn.bgcolor("lightgreen")
tess = turtle.Turtle()


def draw_housing():
    """ Draw a nice housing to hold the traffic lights """
    tess.hideturtle()
    tess.pensize(3)
    tess.color("black", "darkgrey")
    tess.begin_fill()
    tess.forward(80)
    tess.left(90)
    tess.forward(200)
    tess.circle(40, 180)
    tess.forward(200)
    tess.left(90)
    tess.end_fill()
    tess.penup()

def h1():
    global state_num
    wn.bye()
def advance_state_machine():
    global state_num
    tess_green.hideturtle()
    tess_orange.hideturtle()
    tess_red.hideturtle()
    
    if state_num == 0:
        tess_green.showturtle()
        state_num = 1
    elif state_num == 1:
        tess_orange.showturtle()
        state_num = 2
    else:
        tess_red.showturtle()
        state_num = 0
    wn.onkey(h1, "space")
    wn.ontimer(advance_state_machine, 500)
        
tess_green = turtle.Turtle()
tess_green.hideturtle()
tess_green.penup()
tess_green.goto(40, 50)
tess_green.shape("circle")
tess_green.shapesize(3)
tess_green.fillcolor("green")
        
tess_orange = turtle.Turtle()
tess_orange.hideturtle()
tess_orange.penup()
tess_orange.goto(40, 120)
tess_orange.shape("circle")
tess_orange.shapesize(3)
tess_orange.fillcolor("orange")
        
tess_red = turtle.Turtle()
tess_red.hideturtle()
tess_red.penup()
tess_red.goto(40, 190)
tess_red.shape("circle")
tess_red.shapesize(3)
tess_red.fillcolor("red")
        
        
wn.listen()
state_num = 0
draw_housing()
advance_state_machine()
wn.mainloop()

# %%
#exercise 4
import turtle # Tess becomes a traffic light.

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Tess becomes a traffic light!")
wn.bgcolor("lightgreen")
tess = turtle.Turtle()


def draw_housing():
    """ Draw a nice housing to hold the traffic lights """
    tess.hideturtle()
    tess.pensize(3)
    tess.color("black", "darkgrey")
    tess.begin_fill()
    tess.forward(80)
    tess.left(90)
    tess.forward(200)
    tess.circle(40, 180)
    tess.forward(200)
    tess.left(90)
    tess.end_fill()
    tess.penup()

def h1():
    global state_num
    wn.bye()

def advance_state_machine():
    global state_num
    tess_green.fillcolor("black")
    tess_orange.fillcolor("black")
    tess_red.fillcolor("black")
    if state_num == 0:
        tess_green.fillcolor("green")
        state_num = 1
    elif state_num == 1:
        tess_orange.fillcolor("orange")
        state_num = 2
    else:
        tess_red.fillcolor("red")
        state_num = 0
    wn.onkey(h1, "space")
    wn.ontimer(advance_state_machine, 500)

draw_housing()
        
tess_green = turtle.Turtle()
tess_green.shape("circle")
tess_green.shapesize(3)
tess_green.fillcolor("black")
tess_green.hideturtle()
tess_green.penup()
tess_green.goto(40,50)
tess_green.showturtle()
        
tess_orange = turtle.Turtle()
tess_orange.shape("circle")
tess_orange.shapesize(3)
tess_orange.fillcolor("black")
tess_orange.hideturtle()
tess_orange.penup()
tess_orange.goto(40,120)
tess_orange.showturtle()
        
tess_red = turtle.Turtle()
tess_red.shape("circle")
tess_red.shapesize(3)
tess_red.fillcolor("black")
tess_red.hideturtle()
tess_red.penup()
tess_red.goto(40,190)
tess_red.showturtle()
        
        
wn.listen()
state_num = 0

advance_state_machine()
wn.mainloop()

# %%
#exercise 5
import turtle # Tess becomes a traffic light.

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Tess becomes a traffic light!")
wn.bgcolor("lightgreen")
tess = turtle.Turtle()


def draw_housing():
    """ Draw a nice housing to hold the traffic lights """
    tess.hideturtle()
    tess.pensize(3)
    tess.color("black", "darkgrey")
    tess.begin_fill()
    tess.forward(80)
    tess.left(90)
    tess.forward(200)
    tess.circle(40, 180)
    tess.forward(200)
    tess.left(90)
    tess.end_fill()
    tess.penup()

def h1():
    global state_num
    wn.bye()
#exercise 4
import turtle # Tess becomes a traffic light.

turtle.setup(400,500)
wn = turtle.Screen()
wn.title("Tess becomes a traffic light!")
wn.bgcolor("lightgreen")
tess = turtle.Turtle()


def draw_housing():
    """ Draw a nice housing to hold the traffic lights """
    tess.hideturtle()
    tess.pensize(3)
    tess.color("black", "darkgrey")
    tess.begin_fill()
    tess.forward(80)
    tess.left(90)
    tess.forward(200)
    tess.circle(40, 180)
    tess.forward(200)
    tess.left(90)
    tess.end_fill()
    tess.penup()

def h1():
    global state_num
    wn.bye()

def advance_state_machine():
    global state_num
    tess_green.fillcolor("black")
    tess_orange.fillcolor("black")
    tess_red.fillcolor("black")
    if state_num == 0:
        tess_green.fillcolor("green")
        state_num = 1
        wn.ontimer(advance_state_machine, 3000)
    elif state_num == 1:
        tess_green.fillcolor("green")
        tess_orange.fillcolor("orange")
        state_num = 2
        wn.ontimer(advance_state_machine, 1000)
    elif state_num == 2:
        tess_orange.fillcolor("orange")
        state_num = 3
        wn.ontimer(advance_state_machine, 1000)
    else:
        tess_red.fillcolor("red")
        state_num = 0
        wn.ontimer(advance_state_machine, 2000)
        
    wn.onkey(h1, "space")

draw_housing()
        
tess_green = turtle.Turtle()
tess_green.shape("circle")
tess_green.shapesize(3)
tess_green.fillcolor("black")
tess_green.hideturtle()
tess_green.penup()
tess_green.goto(40,50)
tess_green.showturtle()
        
tess_orange = turtle.Turtle()
tess_orange.shape("circle")
tess_orange.shapesize(3)
tess_orange.fillcolor("black")
tess_orange.hideturtle()
tess_orange.penup()
tess_orange.goto(40,120)
tess_orange.showturtle()
        
tess_red = turtle.Turtle()
tess_red.shape("circle")
tess_red.shapesize(3)
tess_red.fillcolor("black")
tess_red.hideturtle()
tess_red.penup()
tess_red.goto(40,190)
tess_red.showturtle()
        
        
wn.listen()
state_num = 0

advance_state_machine()
wn.mainloop()

# %%
#exercise 6 - tennis score
